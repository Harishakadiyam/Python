# %%
if True:
    print('Data Science')
# Out:
# Data Science

# %%
if True:
    print('Data Science')

    print('How are you')
# Out:
# Data Science
# How are you

# %%
if False:
    print('Data Science')

print('bye for now')
# Out:
# bye for now

# %%
if True:
    print('Data Science')
else:
    print('bye for now')
# Out:
# Data Science

# %%
if False:
    print('Data Science')
else:
    print('bye for now')
# Out:
# bye for now

# %%
x=6

r = x%2

if r ==0:
    print('Even number')
if r ==1:
    print('Odd number')
# Out:
# Even number

# %%
x=6

r = x%2

if r ==0:
    print('Even number')
if r ==1:
    print('Odd number')
# Out:
# Even number

# %%
x=5

r = x%2

if r ==0:
    print('Even number')
else:
    print('Odd number')
# Out:
# Odd number

# %%
x = 6

r = x % 2

if r ==0:
   print('Even number')
   if x>5:
       print('Greater number')
   else:
       print('smaller number')
else:
 print('Odd number')
# Out:
# Even number
# Greater number

# %%
x = 3
if x == 1:
    print('one')
if x ==2:
    print('two')
if x ==3:
    print('three')
if x ==4:
    print('four')
# Out:
# three

# %%
x = 10
if x == 1:
    print('one')
if x ==2:
    print('two')
if x ==3:
    print('three')
if x ==4:
    print('four')

else:
    print('number not found')
# Out:
# number not found

# %%
num = int(input("enter a number:"))
if num > 0:
 print("positive")
elif num < 0:
 print("negative")
else:
 print("zero")
# Out:
# enter a number: 3
# positive

# %%
age = 21

if age >=18:
    print("Eligible for vote.")
else:
    print("not Eligible")
# Out:
# Eligible for vote.

# %%
age = 3

if age >= 5:
    print("Eligible to watch movie.")
else:
    print("Not Eligible to watch movie.")
# Out:
# Not Eligible to watch movie.

# %%
print('Data Science')
print('Data Science')
print('Data Science')
print('Data Science')
# Out:
# Data Science
# Data Science
# Data Science
# Data Science

# %%
#LOOPS
